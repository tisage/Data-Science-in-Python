# %% [markdown]
# # Pandas Library Practice II
#
# - Using iloc, loc, & ix to select rows and columns
#
# Since May 2018
#
# Tianyu

# %% [markdown]
# ## Pandas Data Selection
# There are multiple ways to select and index rows and columns from Pandas DataFrames. I find tutorials online focusing on advanced selections of row and column choices a little complex for my requirements.
#
# ### Selection Options
# There’s three main options to achieve the selection and indexing activities in Pandas, which can be confusing. The three selection cases and methods covered in this post are:
#
# - Selecting data by row numbers (.iloc)
# - Selecting data by label or by a conditional statment (.loc)
# - Selecting in a hybrid approach (.ix) (now Deprecated in Pandas 0.20.1) (Skip)
#
# ### Data Setup
#
# ![loc selection](pic/Pandas-selections-and-indexing.png)
#
# This blog post, inspired by other tutorials, describes selection activities with these operations. The tutorial is suited for the general data science situation where, typically I find myself:
#
# - Each row in your data frame represents a data sample.
# - Each column is a variable, and is usually named. I rarely select columns without their names.
# - I need to quickly and often select relevant rows from the data frame for modelling and visualisation activities.
#
#
#
# ### Selection and Indexing Methods for Pandas DataFrames
# For these explorations we’ll need some sample data – I downloaded the uk-500 sample data set from www.briandunning.com. This data contains artificial names, addresses, companies and phone numbers for fictitious UK characters.
#
# To follow along, you can download the .csv file here. Load the data as follows

# %%
import pandas as pd
import random
 
# read the data from the downloaded CSV file.
data = pd.read_csv('data/uk-500.csv')

# set a numeric id for use as an index for examples.
data['id'] = [random.randint(0,1000) for x in range(data.shape[0])]
 
data.head(5)
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web   id
# 0  http://www.alandrosenburgcpapc.co.uk  506
# 1     http://www.capgeminiamerica.co.uk  798
# 2      http://www.elliottjohnwesq.co.uk  544
# 3          http://www.mcmahanbenl.co.uk  801
# 4        http://www.champagneroom.co.uk  323

# %% [markdown]
# ## 1. Selecting pandas data using “iloc”
# The iloc indexer for Pandas Dataframe is used for integer-location based indexing / selection by position.
#
# The iloc indexer syntax is data.iloc[<row selection>, <column selection>], which is sure to be a source of confusion for R users. “iloc” in pandas is used to select rows and columns by number, in the order that they appear in the data frame. You can imagine that each row has a row number from 0 to the total rows (data.shape[0])  and iloc[] allows selections based on these numbers. The same applies for columns (ranging from 0 to data.shape[1] )
#
# There are two “arguments” to iloc – a row selector, and a column selector.  For example:

# %%
# Single selections using iloc and DataFrame

# Rows:
data.iloc[0] # first row of data frame (Aleshia Tomkiewicz) - Note a Series data type output.
data.iloc[1] # second row of data frame (Evan Zigomalas)
data.iloc[-1] # last row of data frame (Mi Richan)

# Columns:
data.iloc[:,0] # first column of data frame (first_name)
data.iloc[:,1] # second column of data frame (last_name)
data.iloc[:,-1].head() # last column of data frame (id)
# Out:
# 0    506
# 1    798
# 2    544
# 3    801
# 4    323
# Name: id, dtype: int64

# %% [markdown]
# Multiple columns and rows can be selected together using the .iloc indexer.

# %%
# Multiple row and column selections using iloc and DataFrame
data.iloc[0:5] # first five rows of dataframe
data.iloc[:, 0:2] # first two columns of data frame with all rows
data.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
data.iloc[0:5, 5:8] # first 5 rows and 5th, 6th, 7th columns of data frame (county -> phone1).
# Out:
#             county    postal        phone1
# 0             Kent   CT2 7PP  01835-703597
# 1  Buckinghamshire  HP11 2AX  01937-864715
# 2      Bournemouth   BH6 3BE  01347-368222
# 3     Lincolnshire  DN36 5RP  01912-771311
# 4    West Midlands   B70 9DT  01547-429341

# %% [markdown]
# here’s two gotchas to remember when using iloc in this manner:
#
# 1. Note that .iloc returns a **Pandas Series** when one row is selected, and a **Pandas DataFrame** when multiple rows are selected, or if any column in full is selected. To counter this, pass a single-valued list if you require DataFrame output.
#
#
# 2. When selecting multiple columns or multiple rows in this manner, remember that in your selection e.g.[1:5], the rows/columns selected will run from the first number to one minus the second number. e.g. [1:5] will go 1,2,3,4., [x,y] goes from x to y-1.

# %% [markdown]
# ## 2. Selecting pandas data using “loc”
# The Pandas loc indexer can be used with DataFrames for two different use cases:
#
# - a.) Selecting rows by label/index
# - b.) Selecting rows with a boolean / conditional lookup
# The loc indexer is used with the same syntax as iloc: **data.loc[<row selection>, <column selection>]**.
#
# ### 2a. Label-based / Index-based indexing using .loc
# Selections using the loc method are based on the index of the data frame (if any). Where the index is set on a DataFrame, using <code>df.set_index()</code>, the .loc method directly selects based on index values of any rows. For example, setting the index of our test data frame to the persons “last_name”:

# %%
data.set_index("last_name", inplace=True)
data.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# Tomkiewicz  01835-703597  01944-369967     atomkiewicz@hotmail.com
# Zigomalas   01937-864715  01714-737668    evan.zigomalas@gmail.com
# Andrade     01347-368222  01935-821636  france.andrade@hotmail.com
# Mcwalters   01912-771311  01302-601380         ulysses@hotmail.com
# Veness      01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                              web   id
# last_name
# Tomkiewicz  http://www.alandrosenburgcpapc.co.uk  506
# Zigomalas      http://www.capgeminiamerica.co.uk  798
# Andrade         http://www.elliottjohnwesq.co.uk  544
# Mcwalters           http://www.mcmahanbenl.co.uk  801
# Veness            http://www.champagneroom.co.uk  323

# %% [markdown]
# Now with the index set, we can directly select rows for different “last_name” values using .loc[<label>]  – either singly, or in multiples. For example:

# %%
data.loc['Andrade']
# Out:
# first_name                                France
# company_name                 Elliott, John W Esq
# address                             8 Moor Place
# city              East Southbourne and Tuckton W
# county                               Bournemouth
# postal                                   BH6 3BE
# phone1                              01347-368222
# phone2                              01935-821636
# email                 france.andrade@hotmail.com
# web             http://www.elliottjohnwesq.co.uk
# id                                           544
# Name: Andrade, dtype: object

# %%
data.loc[['Andrade','Veness']]
# Out:
#           first_name         company_name            address  \
# last_name
# Andrade       France  Elliott, John W Esq       8 Moor Place
# Veness        Tyisha       Champagne Room  5396 Forth Street
#
#                                      city         county   postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness         Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#                  phone1        phone2                       email  \
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                         web   id
# last_name
# Andrade    http://www.elliottjohnwesq.co.uk  544
# Veness       http://www.champagneroom.co.uk  323

# %% [markdown]
# Select columns with .loc using the names of the columns. In most of my data work, typically I have named columns, and use these named selections.

# %%
data.loc[['Andrade','Veness'],['first_name','address','city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %% [markdown]
# You can select ranges of index labels – the selection </code>data.loc[‘Bruch’:’Julio’]</code> will return all rows in the data frame between the index entries for “Bruch” and “Julio”. The following examples should now make sense:

# %%
# Change the index to be based on the 'id' column
data.set_index('id', inplace=True)

# %%
data.head()
# Out:
#     first_name             company_name            address  \
# id
# 506    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# 798       Evan       Cap Gemini America        5 Binney St
# 544     France      Elliott, John W Esq       8 Moor Place
# 801    Ulysses           Mcmahan, Ben L      505 Exeter Rd
# 323     Tyisha           Champagne Room  5396 Forth Street
#
#                                city           county    postal        phone1  \
# id
# 506               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 798                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 544  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 801              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 323      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#            phone2                       email  \
# id
# 506  01944-369967     atomkiewicz@hotmail.com
# 798  01714-737668    evan.zigomalas@gmail.com
# 544  01935-821636  france.andrade@hotmail.com
# 801  01302-601380         ulysses@hotmail.com
# 323  01290-367248   tyisha.veness@hotmail.com
#
#                                       web
# id
# 506  http://www.alandrosenburgcpapc.co.uk
# 798     http://www.capgeminiamerica.co.uk
# 544      http://www.elliottjohnwesq.co.uk
# 801          http://www.mcmahanbenl.co.uk
# 323        http://www.champagneroom.co.uk

# %%
# select the row with 'id' = 506
data.loc[506]
# Out:
# first_name                                   Aleshia
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# Name: 506, dtype: object

# %% [markdown]
# Note that in the last example, data.loc[487] (the row with index value 487) is not equal to data.iloc[487] (the 487th row in the data). The index of the DataFrame can be out of numeric order, and/or a string or multi-value.

# %% [markdown]
# ### 2b. Boolean / Logical indexing using .loc
# Conditional selections with boolean arrays using **data.loc[<selection>]** is the most common method that I use with Pandas DataFrames. With boolean indexing or logical selection, you pass an array or Series of True/False values to the .loc indexer to select the rows where your Series has True values.
#
# In most use cases, you will make selections based on the values of different columns in your data set.
#
# For example, the statement data[‘first_name’] == ‘Antonio’] produces a Pandas Series with a True/False value for every row in the ‘data’ DataFrame, where there are “True” values for the rows where the first_name is “Antonio”. These type of boolean arrays can be passed directly to the .loc indexer as so:

# %%
# Select rows with first name Antonio, # and all columns between 'city' and 'email'
data.loc[data['first_name'] == 'Antonio', 'city':'email']
# Out:
#                                city         county    postal        phone1  \
# id
# 651  Little Parndon and Hare Street  Hertfordshire  CM20 2HT  01559-403415
# 786                  Gaer Community        Newport  NP20 3DE  01463-409090
# 576                        Ipplepen          Devon  TQ12 5LL  01324-171614
#
#            phone2                            email
# id
# 651  01388-777812     antonio.villamarin@gmail.com
# 786  01242-318420  antonio_glasford@glasford.co.uk
# 576  01442-946357         antonio.heilig@gmail.com

# %% [markdown]
# As before, a second argument can be passed to .loc to select particular columns out of the data frame. Again, columns are referred to by name for the loc indexer and can be a single string, a list of columns, or a slice “:” operation.

# %%
data.loc[data['first_name'] == 'Erasmo', ['city','email']]
# Out:
#                  city                         email
# id
# 496  Darton West Ward  erasmo.talentino@hotmail.com
# 918       Sunningdale             egath@hotmail.com
# 560          Mortehoe       erasmo_rhea@hotmail.com

# %% [markdown]
# Note that when selecting columns, if one column only is selected, the .loc operator returns a Series. For a single column DataFrame, use a one-element list to keep the DataFrame format, for example:

# %%
data.loc[data['first_name'] == 'Antonio', 'email']
# Out:
# id
# 651       antonio.villamarin@gmail.com
# 786    antonio_glasford@glasford.co.uk
# 576           antonio.heilig@gmail.com
# Name: email, dtype: object

# %%
data.loc[data['first_name'] == 'Antonio', ['email']]
# Out:
#                                email
# id
# 651     antonio.villamarin@gmail.com
# 786  antonio_glasford@glasford.co.uk
# 576         antonio.heilig@gmail.com

# %% [markdown]
# Make sure you understand the following additional examples of .loc selections for clarity:

# %%
# Select rows where the email column ends with 'hotmail.com', include all columns
data.loc[data['email'].str.endswith("hotmail.com")]
# Out:
#      first_name                    company_name                     address  \
# id
# 506     Aleshia         Alan D Rosenburg Cpa Pc                14 Taylor St
# 544      France             Elliott, John W Esq                8 Moor Place
# 801     Ulysses                  Mcmahan, Ben L               505 Exeter Rd
# 323      Tyisha                  Champagne Room           5396 Forth Street
# 844        Marg   Wrangle Hill Auto Auct & Slvg            7457 Cowl St #70
# 42         Lura                 Bizerba Usa Inc            929 Augustine St
# 481      Dewitt            Rittenhouse Motor Co               7 Richmond St
# 100        Tess                     Smart Signs               61 Rossett St
# 225      German   Jackson & Heit Machine Co Inc              7 Shenstone St
# 987        Luis        Wa Inst For Plcy Studies             2 Birchfield Rd
# 829       Ciara                   Wmgl 101.7 Fm             7523 Kempton Rd
# 886     Alethea            Hughlett, Henry T Jr              6305 Elstow St
# 184     Vicente   B & S Tool And Cutter Svc Inc  3060 St Ambrose Grove #261
# 884       Craig               Berry, John M Esq         8388 Bessemer St #5
# 717      Jenise            Alden, Michael H Esq               87 Pownall Sq
# 20       Annett               Guynes Design Inc      5562 Fairfield St #847
# 939   Domonique          Marketing Horizons Inc                95 Denton St
# 814     Chantay       Brewster Wallcoverings Co            763 Parkfield Rd
# 383     Stefany              L & L Sales Co Inc          636 Portland Place
# 429               http://www.jurdemscottesq.co.uk
# 94                  http://www.lindnerfunds.co.uk
# 721             http://www.donaldgnelsonesq.co.uk
# 867   http://www.nelsonwrighthaworthgolfcrs.co.uk
#
# [114 rows x 10 columns]

# %%
# Select rows with last_name equal to some values, all columns
data.loc[data['first_name'].isin(['France', 'Tyisha', 'Eric'])]
# Out:
#     first_name             company_name            address  \
# id
# 544     France      Elliott, John W Esq       8 Moor Place
# 323     Tyisha           Champagne Room  5396 Forth Street
# 209       Eric  Thompson, Michael C Esq       9472 Lind St
#
#                                city            county    postal        phone1  \
# id
# 544  East Southbourne and Tuckton W       Bournemouth   BH6 3BE  01347-368222
# 323      Greets Green and Lyng Ward     West Midlands   B70 9DT  01547-429341
# 209                      Desborough  Northamptonshire  NN14 2GH  01969-886290
#
#            phone2                       email  \
# id
# 544  01935-821636  france.andrade@hotmail.com
# 323  01290-367248   tyisha.veness@hotmail.com
# 209  01545-817375          erampy@rampy.co.uk
#
#                                       web
# id
# 544      http://www.elliottjohnwesq.co.uk
# 323        http://www.champagneroom.co.uk
# 209  http://www.thompsonmichaelcesq.co.uk

# %%
# Select rows with first name Antonio AND hotmail email addresses
data.loc[data['email'].str.endswith("gmail.com") & (data['first_name'] == 'Antonio')]
# Out:
#     first_name          company_name                address  \
# id
# 651    Antonio      Combs Sheetmetal  353 Standish St #8264
# 576    Antonio  Radisson Suite Hotel         35 Elton St #3
#
#                                city         county    postal        phone1  \
# id
# 651  Little Parndon and Hare Street  Hertfordshire  CM20 2HT  01559-403415
# 576                        Ipplepen          Devon  TQ12 5LL  01324-171614
#
#            phone2                         email  \
# id
# 651  01388-777812  antonio.villamarin@gmail.com
# 576  01442-946357      antonio.heilig@gmail.com
#
#                                      web
# id
# 651     http://www.combssheetmetal.co.uk
# 576  http://www.radissonsuitehotel.co.uk

# %%
# A lambda function that yields True/False values can also be used.
# Select rows where the company name has 4 words in it.
data.loc[data['company_name'].apply(lambda x: len(x.split(' ')) == 4)]
# Out:
#       first_name                   company_name                    address  \
# id
# 544       France            Elliott, John W Esq               8 Moor Place
# 209         Eric        Thompson, Michael C Esq               9472 Lind St
# 711  Charlesetta               Cain, John M Esq                5 Hygeia St
# 317      Michell            Weiss Spirt & Guyer                 89 Noon St
# 263        Edgar          Crowan, Kenneth W Esq              99 Guthrie St
# 153          Mee       Galloway Electric Co Inc              9 Pengwern St
# 459        Peter     Niagara Custombuilt Mfg Co            4410 Tarlton St
# 948       Martha         Curtin, Patricia M Esq           148 Rembrandt St
# 119      Tamesha            Wilhelm, James E Jr         2200 Nelson St #58
# 230      Leonard   Arctic Star Distributing Inc              41 Canning St
# 281     Svetlana       Lensbower, Gregory L Esq            8289 Cadogan St
# 528        Karma                J C S Machinery               1 Birkett St
# 819         Reed           Berick, Joseph G Esq         5147 Blackstone St
# 636        Milly      Bridgeway Plan For Health      129 Alexander Pope St
# 886      Alethea           Hughlett, Henry T Jr             6305 Elstow St
# 236    Margurite     Penrose Place Pharmacy Inc        218 Greenbank Drive
# 718             http://www.ciociajamesaesq.co.uk
# 324      http://www.hardwarespecialtycoinc.co.uk
# 837         http://www.goldbergstephenmesq.co.uk
# 714           http://www.millerwilliameiii.co.uk
# 433          http://www.schwartzthomaseesq.co.uk
# 116   http://www.allianceconstructioncoinc.co.uk
# 208           http://www.greatclipsforhair.co.uk
# 368   http://www.rockspringspetroleumequip.co.uk
# 721            http://www.donaldgnelsonesq.co.uk
# 743       http://www.bfgfederalcreditunion.co.uk
#
# [192 rows x 10 columns]

# %%
# Selections can be achieved outside of the main .loc for clarity:
# Form a separate variable with your selections:
idx = data['company_name'].apply(lambda x: len(x.split(' ')) == 4)
# Select only the True values in 'idx' and only the 3 columns specified:
data.loc[idx, ['email', 'first_name', 'company']]
# Out:
# /opt/ds/lib/python3.4/site-packages/ipykernel_launcher.py:5: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """
# /opt/ds/lib/python3.4/site-packages/pandas/core/indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                     email   first_name  company
# id
# 544            france.andrade@hotmail.com       France      NaN
# 209                    erampy@rampy.co.uk         Eric      NaN
# 711             charlesetta_erm@gmail.com  Charlesetta      NaN
# 317            mthrossell@throssell.co.uk      Michell      NaN
# 263                 edgar.kanne@yahoo.com        Edgar      NaN
# 153                mee.lapinski@yahoo.com          Mee      NaN
# 459             peter_gutierres@yahoo.com        Peter      NaN
# 948                mteplica@teplica.co.uk       Martha      NaN
# 119                  tveigel@veigel.co.uk      Tamesha      NaN
# 230                  lkufner@kufner.co.uk      Leonard      NaN
# 281          svetlana_tauras@tauras.co.uk     Svetlana      NaN
# 528                     kquarto@gmail.com        Karma      NaN
# 819              reed_weisinger@yahoo.com         Reed      NaN
# 636                       milly@gmail.com        Milly      NaN
# 886                   alethea@hotmail.com      Alethea      NaN
# 236                  mloperfido@gmail.com    Margurite      NaN
# 794                     vernice@yahoo.com      Vernice      NaN
# 884                     craig@hotmail.com        Craig      NaN
# 717              jenise.dulle@hotmail.com       Jenise      NaN
# 964                      melina@gmail.com       Melina      NaN
# 679                    tclapham@gmail.com         Tina      NaN
# 249            carrol_kunimitsu@yahoo.com       Carrol      NaN
# 862                        alba@gmail.com         Alba      NaN
# 623        rory_neufville@neufville.co.uk         Rory      NaN
# 575               justine_salta@yahoo.com      Justine      NaN
# 513           tequila.chisum@chisum.co.uk      Tequila      NaN
# 815                 mconsolazio@yahoo.com     Maybelle      NaN
# 289                   margarett@gmail.com    Margarett      NaN
# 790             lindsay_yadao@yadao.co.uk      Lindsay      NaN
# 914  stevie_stifflemire@stifflemire.co.uk       Stevie      NaN
# ..                                    ...          ...      ...
# 169                      shelia@gmail.com       Shelia      NaN
# 549               evelynn.frede@gmail.com      Evelynn      NaN
# 238                       dusti@gmail.com        Dusti      NaN
# 207                  lstackpole@yahoo.com        Leana      NaN
# 962                   man.homer@gmail.com          Man      NaN
# 229             arletta_naomi@naomi.co.uk      Arletta      NaN
# 423                        npao@gmail.com         Nell      NaN
# 142              alayna_hoyal@hotmail.com       Alayna      NaN
# 316                     royce@hotmail.com        Royce      NaN
# 370             cherelle_sorrel@gmail.com     Cherelle      NaN
# 364            dudley_dibartolo@yahoo.com       Dudley      NaN
# 606               nettie.aldaco@yahoo.com       Nettie      NaN
# 178                     carline@yahoo.com      Carline      NaN
# 44                    lovetta@study.co.uk      Lovetta      NaN
# 422              paul.farrin@farrin.co.uk         Paul      NaN
# 891                         ona@yahoo.com          Ona      NaN
# 734            vschellenberge@hotmail.com        Vicky      NaN
# 945           rusty.adelsperger@yahoo.com        Rusty      NaN
# 254           teresita_gesell@hotmail.com     Teresita      NaN
# 237             evangelina.gius@yahoo.com   Evangelina      NaN
# 718                    domitila@gmail.com     Domitila      NaN
# 324                  carlton@blyler.co.uk      Carlton      NaN
# 837                  peggy.khov@gmail.com        Peggy      NaN
# 714  isabella_piatkowski@piatkowski.co.uk     Isabella      NaN
# 433            tijuana.machalek@gmail.com      Tijuana      NaN
# 116               ahmad.alsaqri@yahoo.com        Ahmad      NaN
# 208          jacquelyne_reibman@yahoo.com   Jacquelyne      NaN
# 368               isabelle.kono@yahoo.com     Isabelle      NaN
# 721                    elbert@hotmail.com       Elbert      NaN
# 743             celestina_keeny@gmail.com    Celestina      NaN
#
# [192 rows x 3 columns]

# %% [markdown]
# Logical selections and boolean Series can also be passed to the generic [] indexer of a pandas DataFrame and will give the same results: data.loc[data[‘id’] == 9] == data[data[‘id’] == 9] .
#
# ## Setting values in DataFrames using .loc
# With a slight change of syntax, you can actually update your DataFrame in the same statement as you select and filter using .loc indexer. This particular pattern allows you to update values in columns depending on different conditions.
#
# **The setting operation does not make a copy of the data frame, but edits the original data.**
#
# As an example:

# %%
data = data.reset_index(drop=False)
data.head()
# Out:
#      index   id first_name                    company_name  \
# 495    495  136      Avery      Plaza Gourmet Delicatessen
# 496    496  122       Reid            Fitzgerald, Edward J
# 497    497  625  Charlette              Furey & Associates
# 498    498  743  Celestina        Bfg Federal Credit Union
# 499    499  867         Mi  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 495  9166 Devon St #905  Knightsbridge and Belgravia Wa   Greater London
# 496        70 Foster St        Inverness Ness-Side Ward         Highland
# 497     714 Fonthill Rd                Darton West Ward  South Yorkshire
# 498         9 Milton St                Consett North ED    County Durham
# 499     6 Norwood Grove               Tanworth-in-Arden     Warwickshire
#
#        postal        phone1        phone2                      email  \
# 495  SW1W 8JY  01748-625058  01369-185737           avery@veit.co.uk
# 496   IV2 6WT  01916-963261  01370-319414     reuresti@euresti.co.uk
# 497   S75 5EJ  01888-152110  01301-312487   cbrenning@brenning.co.uk
# 498   DH8 5LP  01877-379681  01600-463475  celestina_keeny@gmail.com
# 499   B94 5RZ  01451-785624  01202-738406             mi@hotmail.com
#
#                                              web
# 495    http://www.plazagourmetdelicatessen.co.uk
# 496           http://www.fitzgeraldedwardj.co.uk
# 497             http://www.fureyassociates.co.uk
# 498       http://www.bfgfederalcreditunion.co.uk
# 499  http://www.nelsonwrighthaworthgolfcrs.co.uk

# %%
# Change the first name of all rows with an ID greater than 2000 to "John"
data.loc[data['id'] > 2000, "first_name"] = "John"
